# %%
from itertools import chain
from typing import List


def _word2char(reference: List[List[str]], hypothesis: List[List[str]]):
    # tokenize each word into an integer
    vocabulary = set(chain(*reference, *hypothesis))

    if "" in vocabulary:
        raise ValueError(
            "Empty strings cannot be a word. "
            "Please ensure that the given transform removes empty strings."
        )

    word2char = dict(zip(vocabulary, range(len(vocabulary))))

    reference_chars = [
        "".join([chr(word2char[w]) for w in sentence]) for sentence in reference
    ]
    hypothesis_chars = [
        "".join([chr(word2char[w]) for w in sentence]) for sentence in hypothesis
    ]

    return reference_chars, hypothesis_chars

# %%
from itertools import chain
from typing import List


def _word2char(reference: List[List[str]], hypothesis: List[List[str]]):
    # Tokenize each word into an integer
    vocabulary = set(chain(*reference, *hypothesis))

    if "" in vocabulary:
        raise ValueError(
            "Empty strings cannot be a word. "
            "Please ensure that the given transform removes empty strings."
        )

    word2char = dict(zip(vocabulary, range(len(vocabulary))))

    reference_chars = [
        "".join([chr(word2char[w]) for w in sentence]) for sentence in reference
    ]
    hypothesis_chars = [
        "".join([chr(word2char[w]) for w in sentence]) for sentence in hypothesis
    ]

    return word2char, reference_chars, hypothesis_chars

# %%
# Original reference and hypothesis
ref = ['안녕하세요, 반갑습니다 123']
hyp = ['안 반하습니다 123 3']

# Get the word2char mapping and encoded character lists
word2char, word2char_ref, word2char_hyp = _word2char(ref, hyp)

# Create a reverse mapping from characters back to words
char2word = {chr(v): k for k, v in word2char.items()}

# Decipher the encoded character lists back to words
deciphered_ref = [
    [char2word[char] for char in sentence] for sentence in word2char_ref
]
deciphered_hyp = [
    [char2word[char] for char in sentence] for sentence in word2char_hyp
]

# Print the original and deciphered versions
print("Original Reference:", ref)
#print("Encoded Reference:", word2char_ref)
print("Character divided Reference:", deciphered_ref)

print("Original Hypothesis:", hyp)
#print("Encoded Hypothesis:", word2char_hyp)
print("Character divided Hypothesis:", deciphered_hyp)
# Out:
# Original Reference: ['안녕하세요, 반갑습니다 123']
# Character divided Reference: [['안', '녕', '하', '세', '요', ',', ' ', '반', '갑', '습', '니', '다', ' ', '1', '2', '3']]
# Original Hypothesis: ['안 반하습니다 123 3']
# Character divided Hypothesis: [['안', ' ', '반', '하', '습', '니', '다', ' ', '1', '2', '3', ' ', '3']]

# %%
import jiwer

out = jiwer.process_words(
    ref,
    hyp,
)

print(jiwer.visualize_alignment(out))
# Out:
# sentence 1
# REF: 안녕하세요, 반갑습니다 123 *
# HYP:      안 반하습니다 123 3
#           S     S     I
#
# number of sentences: 1
# substitutions=2 deletions=0 insertions=1 hits=1
#
# mer=75.00%
# wil=91.67%
# wip=8.33%
# wer=100.00%

# %%
import jiwer

out = jiwer.process_characters(
    ref,
    hyp,
)

print(jiwer.visualize_alignment(out))
# Out:
# sentence 1
# REF: 안녕하세요, 반갑습니다 12**3
# HYP: 안***** 반하습니다 123 3
#       DDDDD  S      II
#
# number of sentences: 1
# substitutions=1 deletions=5 insertions=2 hits=10
#
# cer=50.00%

# %%
import mecab

mecab = mecab.MeCab()
def wer(ref, hyp ,debug=False, new=True):
    # # 형태소기반 어절분리
    if new:
        r = mecab.morphs(ref)
        h = mecab.morphs(hyp)
    else:
        r = ref.split()
        h = hyp.split()
    
    # # 토큰 기반 어절분리
    # r = [x.replace('▁', '') for x in tokenizer.tokenize(ref)]
    # h = [x.replace('▁', '') for x in tokenizer.tokenize(hyp)]
    
    #costs will holds the costs, like in the Levenshtein distance algorithm
    costs = [[0 for inner in range(len(h)+1)] for outer in range(len(r)+1)]
    # backtrace will hold the operations we've done.
    # so we could later backtrace, like the WER algorithm requires us to.
    backtrace = [[0 for inner in range(len(h)+1)] for outer in range(len(r)+1)]

    OP_OK = 0
    OP_SUB = 1
    OP_INS = 2
    OP_DEL = 3

    DEL_PENALTY=1 # Tact
    INS_PENALTY=1 # Tact
    SUB_PENALTY=1 # Tact
    # First column represents the case where we achieve zero
    # hypothesis words by deleting all reference words.
    for i in range(1, len(r)+1):
        costs[i][0] = DEL_PENALTY*i
        backtrace[i][0] = OP_DEL

    # First row represents the case where we achieve the hypothesis
    # by inserting all hypothesis words into a zero-length reference.
    for j in range(1, len(h) + 1):
        costs[0][j] = INS_PENALTY * j
        backtrace[0][j] = OP_INS

    # computation
    for i in range(1, len(r)+1):
        for j in range(1, len(h)+1):
            if r[i-1] == h[j-1]:
                costs[i][j] = costs[i-1][j-1]
                backtrace[i][j] = OP_OK
            else:
                substitutionCost = costs[i-1][j-1] + SUB_PENALTY # penalty is always 1
                insertionCost    = costs[i][j-1] + INS_PENALTY   # penalty is always 1
                deletionCost     = costs[i-1][j] + DEL_PENALTY   # penalty is always 1

                costs[i][j] = min(substitutionCost, insertionCost, deletionCost)
                if costs[i][j] == substitutionCost:
                    backtrace[i][j] = OP_SUB
                elif costs[i][j] == insertionCost:
                    backtrace[i][j] = OP_INS
                else:
                    backtrace[i][j] = OP_DEL

    # back trace though the best route:
    i = len(r)
    j = len(h)
    numSub = 0
    numDel = 0
    numIns = 0
    numCor = 0
    if debug:
        # print("OP\tREF\tHYP")
        lines = []
    while i > 0 or j > 0:
        if backtrace[i][j] == OP_OK:
            numCor += 1
            i-=1
            j-=1
            if debug:
                lines.append("OK\t" + r[i]+"\t"+h[j])
        elif backtrace[i][j] == OP_SUB:
            numSub +=1
            i-=1
            j-=1
            if debug:
                lines.append("SUB\t" + r[i]+"\t"+h[j])
        elif backtrace[i][j] == OP_INS:
            numIns += 1
            j-=1
            if debug:
                lines.append("INS\t" + "****" + "\t" + h[j])
        elif backtrace[i][j] == OP_DEL:
            numDel += 1
            i-=1
            if debug:
                lines.append("DEL\t" + r[i]+"\t"+"****")
                
    
    if debug:
        reversed_lines = reversed(lines)
        for line in reversed_lines:
            print(line)
        print("Ncor " + str(numCor))
        print("Nsub " + str(numSub))
        print("Ndel " + str(numDel))
        print("Nins " + str(numIns))
        print("WER " + str((numSub + numDel + numIns) / (float) (len(r)))) 
        
        
    return numCor, numSub, numDel, numIns, (numSub + numDel + numIns) / (float) (len(r)), lines, (float) (len(r))

# %%
mecab.morphs(ref[0])
mecab

# %%
numCor, numSub, numDel, numIns, wer_score, lines, _ = wer(ref[0].replace(",", ''), hyp[0], debug=True)
print("C", numCor)
print("S", numSub)
print("D", numDel)
print("I", numIns)
print("WER: ", wer_score)
# Out:
# DEL	안녕	****
# DEL	하	****
# SUB	세요	안
# SUB	반갑	반하
# OK	습니다	습니다
# OK	123	123
# INS	****	3
# Ncor 2
# Nsub 2
# Ndel 2
# Nins 1
# WER 0.8333333333333334
# C 2
# S 2
# D 2
# I 1
# WER:  0.8333333333333334

# %%
from soynlp.hangle import jamo_levenshtein
from soynlp.hangle import levenshtein

def cer2(ref, hyp):
    ref = ref.replace(' ', '')
    hyp = hyp.replace(' ', '')
    
    # print(ref)
    # print(hyp)
    dist = jamo_levenshtein(hyp, ref)
    length = len(ref)
    return dist, length, dist/length

# %%
jamo_levenshtein('안', '아')
# Out:
# 0.3333333333333333

# %%
jamo_levenshtein('안', 'ㅇ')
# Out:
# 0.6666666666666666

# %%
dist, length, cer = cer(ref[0], hyp[0])
dist, length, cer
# Out:
# (6.666666666666667, 14, 0.4761904761904762)

# %%
mistakes = 2 + 1 + 1 
total = 14

# %%
from soynlp.hangle import decompose
for c1, c2 in zip(ref[0], hyp[0]):
    print(decompose(c1), decompose(c2))
# Out:
# ('ㅇ', 'ㅏ', 'ㄴ') ('ㅇ', 'ㅏ', 'ㄴ')
# ('ㄴ', 'ㅕ', 'ㅇ') None
# ('ㅎ', 'ㅏ', ' ') ('ㅂ', 'ㅏ', 'ㄴ')
# ('ㅅ', 'ㅔ', ' ') ('ㅎ', 'ㅏ', ' ')
# ('ㅇ', 'ㅛ', ' ') ('ㅅ', 'ㅡ', 'ㅂ')
# None ('ㄴ', 'ㅣ', ' ')
# None ('ㄷ', 'ㅏ', ' ')
# ('ㅂ', 'ㅏ', 'ㄴ') None
# ('ㄱ', 'ㅏ', 'ㅂ') None
# ('ㅅ', 'ㅡ', 'ㅂ') None
# ('ㄴ', 'ㅣ', ' ') None
# ('ㄷ', 'ㅏ', ' ') None
# None None

# %%
def ser(ref, hyp ,debug=False, new=True):
    lines = []
    # split by phoneme
    r = list(ref)
    h = list(hyp)
    
    #costs will holds the costs, like in the Levenshtein distance algorithm
    costs = [[0 for inner in range(len(h)+1)] for outer in range(len(r)+1)]
    # backtrace will hold the operations we've done.
    # so we could later backtrace, like the WER algorithm requires us to.
    backtrace = [[0 for inner in range(len(h)+1)] for outer in range(len(r)+1)]

    OP_OK = 0
    OP_SUB = 1
    OP_INS = 2
    OP_DEL = 3

    DEL_PENALTY=1 # Tact
    INS_PENALTY=1 # Tact
    SUB_PENALTY=1 # Tact
    # First column represents the case where we achieve zero
    # hypothesis words by deleting all reference words.
    for i in range(1, len(r)+1):
        costs[i][0] = DEL_PENALTY*i
        backtrace[i][0] = OP_DEL

    # First row represents the case where we achieve the hypothesis
    # by inserting all hypothesis words into a zero-length reference.
    for j in range(1, len(h) + 1):
        costs[0][j] = INS_PENALTY * j
        backtrace[0][j] = OP_INS

    # computation
    for i in range(1, len(r)+1):
        for j in range(1, len(h)+1):
            if r[i-1] == h[j-1]:
                costs[i][j] = costs[i-1][j-1]
                backtrace[i][j] = OP_OK
            else:
                substitutionCost = costs[i-1][j-1] + SUB_PENALTY # penalty is always 1
                insertionCost    = costs[i][j-1] + INS_PENALTY   # penalty is always 1
                deletionCost     = costs[i-1][j] + DEL_PENALTY   # penalty is always 1

                costs[i][j] = min(substitutionCost, insertionCost, deletionCost)
                if costs[i][j] == substitutionCost:
                    backtrace[i][j] = OP_SUB
                elif costs[i][j] == insertionCost:
                    backtrace[i][j] = OP_INS
                else:
                    backtrace[i][j] = OP_DEL

    # back trace though the best route:
    i = len(r)
    j = len(h)
    numSub = 0
    numDel = 0
    numIns = 0
    numCor = 0
    if debug:
        # print("OP\tREF\tHYP")
        lines = []
    while i > 0 or j > 0:
        if backtrace[i][j] == OP_OK:
            numCor += 1
            i-=1
            j-=1
            if debug:
                lines.append("OK\t" + r[i]+"\t"+h[j])
        elif backtrace[i][j] == OP_SUB:
            numSub +=1
            i-=1
            j-=1
            if debug:
                lines.append("SUB\t" + r[i]+"\t"+h[j])
        elif backtrace[i][j] == OP_INS:
            numIns += 1
            j-=1
            if debug:
                lines.append("INS\t" + "****" + "\t" + h[j])
        elif backtrace[i][j] == OP_DEL:
            numDel += 1
            i-=1
            if debug:
                lines.append("DEL\t" + r[i]+"\t"+"****")
                
    
    if debug:
        reversed_lines = reversed(lines)
        for line in reversed_lines:
            print(line)
        print("Ncor " + str(numCor))
        print("Nsub " + str(numSub))
        print("Ndel " + str(numDel))
        print("Nins " + str(numIns))
        print("WER " + str((numSub + numDel + numIns) / (float) (len(r)))) 
        
        
    return numCor, numSub, numDel, numIns, (numSub + numDel + numIns) / (float) (len(r)), lines, (float) (len(r))

# %%
from soynlp.hangle import decompose

def cer(ref, hyp ,debug=False, new=True):
    lines = []
    # split by phoneme
    ref = list(ref)
    r = []
    for c in ref:
        ctuple = decompose(c)
        if not ctuple:
            continue
        for ct in ctuple:
            if ct != ' ':
                r.append(ct)
    hyp = list(hyp)
    h = []
    for c in hyp:
        ctuple = decompose(c)
        if not ctuple:
            continue
        for ct in ctuple:
            if ct != ' ':
                h.append(ct)
    
    #costs will holds the costs, like in the Levenshtein distance algorithm
    costs = [[0 for inner in range(len(h)+1)] for outer in range(len(r)+1)]
    # backtrace will hold the operations we've done.
    # so we could later backtrace, like the WER algorithm requires us to.
    backtrace = [[0 for inner in range(len(h)+1)] for outer in range(len(r)+1)]

    OP_OK = 0
    OP_SUB = 1
    OP_INS = 2
    OP_DEL = 3

    DEL_PENALTY=1 # Tact
    INS_PENALTY=1 # Tact
    SUB_PENALTY=1 # Tact
    # First column represents the case where we achieve zero
    # hypothesis words by deleting all reference words.
    for i in range(1, len(r)+1):
        costs[i][0] = DEL_PENALTY*i
        backtrace[i][0] = OP_DEL

    # First row represents the case where we achieve the hypothesis
    # by inserting all hypothesis words into a zero-length reference.
    for j in range(1, len(h) + 1):
        costs[0][j] = INS_PENALTY * j
        backtrace[0][j] = OP_INS

    # computation
    for i in range(1, len(r)+1):
        for j in range(1, len(h)+1):
            if r[i-1] == h[j-1]:
                costs[i][j] = costs[i-1][j-1]
                backtrace[i][j] = OP_OK
            else:
                substitutionCost = costs[i-1][j-1] + SUB_PENALTY # penalty is always 1
                insertionCost    = costs[i][j-1] + INS_PENALTY   # penalty is always 1
                deletionCost     = costs[i-1][j] + DEL_PENALTY   # penalty is always 1

                costs[i][j] = min(substitutionCost, insertionCost, deletionCost)
                if costs[i][j] == substitutionCost:
                    backtrace[i][j] = OP_SUB
                elif costs[i][j] == insertionCost:
                    backtrace[i][j] = OP_INS
                else:
                    backtrace[i][j] = OP_DEL

    # back trace though the best route:
    i = len(r)
    j = len(h)
    numSub = 0
    numDel = 0
    numIns = 0
    numCor = 0
    if debug:
        # print("OP\tREF\tHYP")
        lines = []
    while i > 0 or j > 0:
        if backtrace[i][j] == OP_OK:
            numCor += 1
            i-=1
            j-=1
            if debug:
                lines.append("OK\t" + r[i]+"\t"+h[j])
        elif backtrace[i][j] == OP_SUB:
            numSub +=1
            i-=1
            j-=1
            if debug:
                lines.append("SUB\t" + r[i]+"\t"+h[j])
        elif backtrace[i][j] == OP_INS:
            numIns += 1
            j-=1
            if debug:
                lines.append("INS\t" + "****" + "\t" + h[j])
        elif backtrace[i][j] == OP_DEL:
            numDel += 1
            i-=1
            if debug:
                lines.append("DEL\t" + r[i]+"\t"+"****")
                
    
    if debug:
        reversed_lines = reversed(lines)
        for line in reversed_lines:
            print(line)
        print("Ncor " + str(numCor))
        print("Nsub " + str(numSub))
        print("Ndel " + str(numDel))
        print("Nins " + str(numIns))
        print("WER " + str((numSub + numDel + numIns) / (float) (len(r)))) 
        
        
    return numCor, numSub, numDel, numIns, (numSub + numDel + numIns) / (float) (len(r)), lines, (float) (len(r))

# %%
ref = ['안녕하세요 반갑습니다 123']
hyp = ['안 반하습니다 123 3']

numCor, numSub, numDel, numIns, ser_score, lines, _ = ser(ref[0], hyp[0], debug=True)
print("-"*50)
numCor, numSub, numDel, numIns, cer_score, lines, _ = cer(ref[0], hyp[0], debug=True)
# Out:
# OK	안	안
# DEL	녕	****
# DEL	하	****
# DEL	세	****
# DEL	요	****
# OK
# OK	반	반
# SUB	갑	하
# OK	습	습
# OK	니	니
# OK	다	다
# OK
# OK	1	1
# OK	2	2
# INS	****	3
# INS	****
# OK	3	3
# Ncor 10
# Nsub 1
# Ndel 4
# Nins 2
# WER 0.4666666666666667
# --------------------------------------------------
# OK	ㅇ	ㅇ
# OK	ㅏ	ㅏ
# DEL	ㄴ	****
# OK	ㄴ	ㄴ
# DEL	ㅕ	****
# DEL	ㅇ	****
# DEL	ㅎ	****
# DEL	ㅏ	****
# DEL	ㅅ	****
# DEL	ㅔ	****
# DEL	ㅇ	****
# DEL	ㅛ	****
# OK	ㅂ	ㅂ
# OK	ㅏ	ㅏ
# OK	ㄴ	ㄴ
# SUB	ㄱ	ㅎ
# OK	ㅏ	ㅏ
# DEL	ㅂ	****
# OK	ㅅ	ㅅ
# OK	ㅡ	ㅡ
# OK	ㅂ	ㅂ
# OK	ㄴ	ㄴ
# OK	ㅣ	ㅣ
# OK	ㄷ	ㄷ
# OK	ㅏ	ㅏ
# Ncor 14
# Nsub 1
# Ndel 10
# Nins 0
# WER 0.44

# %%
with open('stuff/predictions_VC-JHJ_Woman_40s-01-08-35.48_test.txt', 'r') as f:
    ref = f.readlines()

with open('stuff/references_VC-JHJ_Woman_40s-01-08-35.48_test.txt', 'r') as f:
    pred = f.readlines()

# %%
ref = [x.strip() for x in ref]
pred = [x.strip() for x in pred]

import re

ref = [re.sub('[!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~]', '', ref.replace('\n', '')).strip() for ref in ref]
pred = [re.sub('[!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~]', '', pred.replace('\n', '')).strip() for pred in pred]

# %%
import evaluate

# Evaluate the model
metric = evaluate.load("wer")
metric_cer = evaluate.load("cer")

wer = 100 * metric.compute(predictions=pred, references=ref)
cer_ = 100 * metric_cer.compute(predictions=pred, references=ref)
print(f"WER: {wer:.2f}%")
print(f"CER: {cer_:.2f}%")
# Out:
# WER: 47.70%
# CER: 27.81%

# %%
ref = ['안녕하세요 반갑습니다 123']
hyp = ['안 반하습니다 123 3']

dist, length, cer_score = cer2(ref[0], hyp[0])
ser = 100 * metric_cer.compute(predictions=hyp, references=ref)
print(f"CER: {cer_score*100}%")
print(f"SER: {ser}%")
# Out:
# CER: 43.58974358974359%
# SER: 46.666666666666664%

# %%
import mecab
mecab = mecab.MeCab()


def remove_sound(text: str) -> str:
    results = []
    for w, p in mecab.pos(text):
        if p == 'IC' and len(w) == 1:
            continue # something do you want
        results.append(w + ' ')
    return ''.join(results)

remove_sound('그래 아 어  hello')
# Out:
# '그래 hello is '

# %%
from soynlp.hangle import decompose, compose

def ignore_similar(text: str) -> str:
    results = []

    for c in text:
        # Try decomposing the character
        phonemes = decompose(c)
        if phonemes is None :
            # If decomposition fails, keep the character as is
            results.append(c)
            continue
        onset, nucleus, coda = phonemes

        if nucleus in ['ㅔ', 'ㅐ', 'ㅒ', 'ㅖ']:
            nucleus = 'ㅔ'
        elif nucleus in  ['ㅙ', 'ㅚ', 'ㅞ']:
            nucleus = 'ㅙ'
        results.append(compose(onset, nucleus, coda))
    return ''.join(results)

# Test the function
print(ignore_similar('안녕하세요 애 게 세 외국인'))
# Out:
# 안녕하세요 에 게 세 왜국인

# %%
decompose('왜')
# Out:
# ('ㅇ', 'ㅙ', ' ')

# %%
total_cer = 0
for r, p in zip(ref, pred):
    dist, length, cer_score = cer2(r, p)
    total_cer += cer_score
total_cer /= len(ref)
print(f"CER: {total_cer:.4f}%")
# Out:
# CER: 0.2559%

# %%
total_ser = 0
total_cer = 0

total_ins1 = 0
total_del1 = 0
total_sub1 = 0

total_ins2 = 0
total_del2 = 0
total_sub2 = 0

for r, p in zip(ref, pred):
    #r = remove_sound(r)
    #p = remove_sound(p)
    #r = ignore_similar(r)
    #p = ignore_similar(p)
    #if not r or not p:
    #    continue
    numCor1, numSub1, numDel1, numIns1, ser_score, lines, total1 = ser(r, p, debug=False)
    numCor2, numSub2, numDel2, numIns2, cer_score, lines, total2 = cer(r, p, debug=False)
    orig_ser = metric_cer.compute(predictions=[p], references=[r])
    orig_cer = cer2(p, r)[2]
    if ser_score != orig_ser:
        print("SER")
        print('ref:', r)
        print('hyp:', p)
        print('or', orig_ser)
        print('my', ser_score)
        print('-'*10)
    if cer_score != orig_cer:
        print("CER")
        print('ref:', r)
        print('hyp:', p)
        print('or', orig_cer)
        print('my', cer_score)
        print('-'*10)
    #dist, length, cer_score = cer2(r, p)
    total_ser += ser_score
    total_cer += cer_score

    total_ins1 += numIns1/total1
    total_del1 += numDel1/total1
    total_sub1 += numSub1/total1

    total_ins2 += numIns2/total2
    total_del2 += numDel2/total2
    total_sub2 += numSub2/total2
total_ser /= len(ref)
total_cer /= len(ref)

total_ins1 /= len(ref)
total_del1 /= len(ref)
total_sub1 /= len(ref)

total_ins2 /= len(ref)
total_del2 /= len(ref)
total_sub2 /= len(ref)



print(f"SER: {total_ser*100:.2f}%")
print(f"CER: {total_cer*100:.2f}%")

print(f"INS SER: {total_ins1*100:.2f}%")
print(f"DEL SER: {total_del1*100:.2f}%")
print(f"SUB SER: {total_sub1*100:.2f}%")

print(f"INS CER: {total_ins2*100:.2f}%")
print(f"DEL CER: {total_del2*100:.2f}%")
print(f"SUB CER: {total_sub2*100:.2f}%")
# Out:
# CER
# ref: 얼리 말하는 말투가 그런거든
# hyp: 원래 말하는 말투가 그런 거더라고
# or 0.2619047619047619
# my 0.26666666666666666
# ----------
# CER
# ref: 그게 오는 거래
# hyp: 떼오는 거래
# or 0.26666666666666666
# my 0.23076923076923078
# ----------
# CER
# ref: 어 이 안 하고
# hyp: 그래요 이제 안 가고
# or 0.45833333333333337
# my 0.7272727272727273
# ----------
# CER
# ref: 우리 엄마가 때는 하는 말이야 뭐 할 때 꼭 엄마랑 사치해라 엄마도 아프다운 거지
# hyp: 우리 엄마가 맨날 하는 말이 뭐 할 때 그 엄마랑 상의해라 엄마도 안타까운거지
# or 0.18279569892473116
# my 0.21621621621621623
# ----------
# CER
# ref: 되게 좋았네
# hyp: 커피를 되게 좋아서
# or 0.5
# my 0.8333333333333334
# ----------
# CER
# ref: 근데 동생이 언니 언니 혜원은 진짜 뭐 그래 언니가 왜 그러니까
# hyp: 이렇게 얘기를 했는데 그 동생이 언니 혀는 진짜 그래 그래서 내가 왜 그러니까
# or 0.47311827956989244
# my 0.5932203389830508
# ----------
# CER
# ref: 아유 내가 밥 살게
# hyp: 아이 내가 밥 살게
# or 0.047619047619047616
# my 0.0625
# ----------
# CER
# ref: 10키로가 얼마야 10키로가
# hyp: 그게 얼마야 10kg가
# or 0.6
# my 0.47368421052631576
# ----------
# CER
# ref: 한동안 안 못 봤어 거기 있어가지고
# hyp: 한동안 안가져갔어 꼴뵈기 싫어가지고
# or 0.3125
# my 0.37142857142857144
# ----------
# CER
# ref: 했지 그러니까 내가 안 한다고 하면
# hyp: 했어야 돼 그러니까 내가 안 한다고 하면
# or 0.16666666666666666
# my 0.1875
# ----------
# CER
# ref: 내가 보니까 내가 자기가 있고 처음에는 그냥 고등고등이 있었나 이런 거야
# hyp: 내가 보니까 내가 장애가 있고 처음에는 그냥 고분고분하니까 그런거야
# or 0.21839080459770113
# my 0.2753623188405797
# ----------
# CER
# ref: 내가 그 친구 입장에서 내가 너를 알아두 20년 넘게 알고
# hyp: 내가 그 친구 입장에서 내가 너를 알아도 20년 넘게 알고
# or 0.014492753623188404
# my 0.02
# ----------
# CER
# ref: 열심히군 알겠어
# hyp: 하면서 뭐 또
# or 1.1333333333333333
# my 0.8947368421052632
# ----------
# CER
# ref: 5만 원 6만 원 이렇게 잡히는데 2개라고 하면 된다 얘기를 했어 거기까지 부었어 막이
# hyp: 5만원 6만 원 이렇게 잡히는데 그 두 배라고 생각하면 된다 얘기를 했어 거기까지 좋았어
# or 0.21296296296296297
# my 0.24675324675324675
# ----------
# CER
# ref: 뭐가 걸린 거 같이 느껴진대
# hyp: 뭐가 걸린 것 같이 느껴진대
# or 0.0303030303030303
# my 0.038461538461538464
# ----------
# CER
# ref: 아
# hyp: 어
# or 0.3333333333333333
# my 0.5
# ----------
# CER
# ref: 응
# hyp: 에휴
# or 0.8333333333333333
# my 1.0
# ----------
# CER
# ref: 진대지
# hyp: 힘들지
# or 0.4444444444444444
# my 0.5714285714285714
# ----------
# SER
# ref: 그래가지고 그런 걸 하는 거예요 오래 알고 오래 얘기하면  그냥 느낌적으로도 알잖아
# hyp: 그래가지고 그런 걸 하는 거 오래 알고 오래 얘기하면 그냥 느낌적으로도 알잖아
# or 0.044444444444444446
# my 0.06521739130434782
# ----------
# CER
# ref: 그래가지고 그런 걸 하는 거예요 오래 알고 오래 얘기하면  그냥 느낌적으로도 알잖아
# hyp: 그래가지고 그런 걸 하는 거 오래 알고 오래 얘기하면 그냥 느낌적으로도 알잖아
# or 0.0625
# my 0.05128205128205128
# ----------
# CER
# ref: 그래가지고 그 밀크티를 막 만들어보려고 내가 애 제로 살 때 그거 아직 중간에 했거든
# hyp: 그래가지고 그 밀크티를 만들어보려고 내가 얘 재료 살 때 내 것까지 주문을 했거든
# or 0.16161616161616163
# my 0.20253164556962025
# ----------
# CER
# ref: 출어요
# hyp: 싫어해
# or 0.5555555555555555
# my 0.7142857142857143
# ----------
# CER
# ref: 그래지는 않은 것 같아 한번 그렇게 대통신거 알으니까 쉬더라고
# hyp: 그러진 않을거 같아 한 번 그게 뒤통수 맞으니까 하기 싫더라고
# or 0.3466666666666666
# my 0.3333333333333333
# ----------
# CER
# ref: 그냥 빳직하는 게 좀 대거 그냥 애들 하고 12시 반부터 10시까지 빳직하는 게 자기한테
# hyp: 그냥 반짝하는 게 좋다고 그냥 애들 하교하고 12시 반부터 4시까지 반짝하는 게 자기한테 맞대
# or 0.2478632478632479
# my 0.2631578947368421
# ----------
# CER
# ref: 그것도 뜨거워
# hyp: 그것도 쏠쏠
# or 0.6
# my 0.46153846153846156
# ----------
# CER
# ref: 뭐 여기 와서 하는 것도 다행히 했어 그래가지고
# hyp: 뭐 여기 와서 아는 것도 다행이지 그래가지고
# or 0.12962962962962962
# my 0.16666666666666666
# ----------
# CER
# ref: 아 그럴 때 하는구나
# hyp: 아 그렇게 하는구나
# or 0.125
# my 0.16666666666666666
# ----------
# CER
# ref: 그 캡스도 한 달 동안 6천원에서 나가요 근데 내가 더 이상 유지 못하게 되는 거야
# hyp: 그리고 캡스도 한 달에 9만 5천 원이 나가요 근데 내가 더 이상 유지 못하겠는거야
# or 0.2424242424242424
# my 0.1780821917808219
# ----------
# CER
# ref: 그래 되게 담담한 척하면서 얘기를 하는데 그게 아니거든 내가 볼 때는 내가 이렇게 나올지 몰랐다고 그랬어
# hyp: 아 그래 되게 담담한 척하면서 얘기를 하는데 그게 아니거든내가 볼 때는 내가 이렇게 나올 줄 몰랐어 몰랐던 것 같아
# or 0.15217391304347827
# my 0.19801980198019803
# ----------
# CER
# ref: 근데 너무 웃겼던 게 나는 다 잊었어야 돼 다 잊었는데 진짜 한 임시 1타가 또 한거야그 후에 너무 싫은것 같은 거야
# hyp: 근데 너무 웃겼던 게 난 다 잊었어 이제 다 잊었는데 진짜 한 일주일 있다가 또 온거야 그 후에 너무 소름 끼치는 거야
# or 0.22222222222222227
# my 0.2523364485981308
# ----------
# CER
# ref: 자기 TV가 포도 농장 한다고 그 일을 도와주는 것 같은데
# hyp: 자기 친구가 포도농장 한다고 그 일 도와주는 거 같던데
# or 0.18181818181818182
# my 0.21568627450980393
# ----------
# CER
# ref: 1줄
# hyp: 일주일
# or 0.7777777777777777
# my 1.6666666666666667
# ----------
# CER
# ref: 내가 그랬어 나한테 뜬금같이 문자가 왔어 내가 네 가게 잘 전년 공부 하나 알았을까 이런 식으로 되는 거야
# hyp: 내가 그랬어 나한테 뜬금없이 문자가 왔어 내가 네 가게에 잘 되는 방법 하나만 알려줄까 이런 식으로 하는 거야
# or 0.18181818181818182
# my 0.21782178217821782
# ----------
# CER
# ref: 알바한테
# hyp: 알바한대
# or 0.16666666666666666
# my 0.2
# ----------
# CER
# ref: 현금은 잡히지 않는 거다 내가 그분이 와서 10초를 뽑아도
# hyp: 현금은 잡히지 않는 거다 내가 그분이 와서 매출표를 뽑아도
# or 0.1111111111111111
# my 0.11320754716981132
# ----------
# CER
# ref: 더 열심히 해봐야겠다
# hyp: 좀 더 열심히 해봐야겠다
# or 0.1
# my 0.14285714285714285
# ----------
# CER
# ref: 따까맣해
# hyp: 깔끔하네
# or 0.6666666666666666
# my 0.7777777777777778
# ----------
# CER
# ref: 나도 또 오갔어
# hyp: 나중에 또 오겠죠
# or 0.38095238095238093
# my 0.6153846153846154
# ----------
# CER
# ref: 막 이렇게 냄새 약해서 나 그거 안 먹거든 근데 얘 거는 들 맛있어
# hyp: 내가 냄새에 약해서 나 그거 안 먹거든 근데 얘 거는 되게 맛있어
# or 0.22666666666666668
# my 0.22580645161290322
# ----------
# CER
# ref: 일요일 아니요 수요일에
# hyp: 일요일 아니면 수요일 날
# or 0.2
# my 0.2608695652173913
# ----------
# CER
# ref: 돌많아 쉬면서 뭐 배우고 배우러 다니기도 하고 다른 카페에 가서 뭐 어떤 걸 또
# hyp: 토요일마다 쉬면서 뭐 배우고 배우러 다니기도 하고 다른 카페 가서 뭐 어떤 걸 또
# or 0.13541666666666669
# my 0.1323529411764706
# ----------
# CER
# ref: 위약금이지요 저게
# hyp: 위약금이 있대요 저게
# or 0.18518518518518517
# my 0.2222222222222222
# ----------
# CER
# ref: 그러면 1시 만원이 그거 자기 쌍
# hyp: 그러니까 이십만원이 그거 합친거 자기 타로
# or 0.4444444444444444
# my 0.6428571428571429
# ----------
# CER
# ref: 한 4시 반동생에서
# hyp: 한 다섯시 반 정도 되면 닫어
# or 0.606060606060606
# my 0.9444444444444444
# ----------
# CER
# ref: 녹음해야 될 거 같아서
# hyp: 녹음해야 될 것 같아서
# or 0.037037037037037035
# my 0.045454545454545456
# ----------
# CER
# ref: 5분 해야 되고 그러면서 그냥 나도 모르고 여기서야 그랬어
# hyp: 오븐도 해야되고 그래야 되는데 내가 그냥 나도 모르고 여기서요 이랬어
# or 0.3103448275862069
# my 0.42
# ----------
# CER
# ref: 어 이사지 안 될 수 있네
# hyp: 어 이사했지 한 달 전에
# or 0.4444444444444444
# my 0.5238095238095238
# ----------
# CER
# ref: 식 언니가 그거 어떻게냐고 마음이 있었냐고 이런 식으로 얘기를 해 내가 아니 그때부터 내 속만 말했지 나 좀 불편하라고
# hyp: 희정이가 하는거 어떻냐고 마음에 드냐고 이런 식으로 얘기를 해 내가 언니 그때부터 내 속마음을 말했지 나 좀 불편하다고
# or 0.2108843537414966
# my 0.25
# ----------
# CER
# ref: 내 난 하고는 얘기해 얘기한 게 아니라 그때 마침 부동산 아줌마가 와갖고 이렇게 돌려보는 때였어
# hyp: 내 놨다고는 얘기 얘기한 게 아니라 그때 마침 부동산 아줌마가 와 갖고 이렇게 둘러보는 때였어
# or 0.07017543859649124
# my 0.07777777777777778
# ----------
# CER
# ref: 뭐보면 오해야겠어
# hyp: 누가 보면 오해하겠어
# or 0.25925925925925924
# my 0.3333333333333333
# ----------
# CER
# ref: 그럼 이렇게 늦게까지 이따 간나게 가면 다음 난에 아침에 오면
# hyp: 너무 웃겨 그다음 이렇게 늦게까지 있다가 간 날 있잖아 가면 그다음 날에 아침에 오면
# or 0.3431372549019608
# my 0.4915254237288136
# ----------
# CER
# ref: 응
# hyp: 그래
# or 0.8333333333333333
# my 1.0
# ----------
# CER
# ref: 어
# hyp: 응
# or 0.6666666666666666
# my 1.0
# ----------
# CER
# ref: 뭐도 있는게 아니라
# hyp: 뭔일 있는 게 아니라
# or 0.16666666666666666
# my 0.2222222222222222
# ----------
# CER
# ref: 그게 좋은 생각이야 돈을 내야지 나는 원하는 집을 하고 그걸 사야지 도와주는 거 아니지 그거는
# hyp: 그게 돈이 중요하냐 돈은 내야지나는 그 언니한테 지불하고 그걸 사야지 도와주는 거 아니지 그거는
# or 0.22499999999999995
# my 0.24444444444444444
# ----------
# CER
# ref: 내 말이야
# hyp: 내 말이
# or 0.3333333333333333
# my 0.2222222222222222
# ----------
# CER
# ref: 그 번 있는거 이거 여기 와서 딱 하고 있잖아 장사를 하고 있어
# hyp: 그건 있는 것 같아요 내가 여기 와서 하고 있잖아 장사를 하고 있잖아
# or 0.24691358024691357
# my 0.3157894736842105
# ----------
# CER
# ref: 없기 때문에 그 부분에서 엄마도 네 그 언니가 그렇게 얘기한다면 말을 하면서 그렇게 얘기를 했어
# hyp: 없기 때문에 그 부분에 대해서 고맙지 네 그 언니가 그렇게 얘기한다면 나는 할말 있다고 그렇게 얘기를 했어
# or 0.20930232558139536
# my 0.2608695652173913
# ----------
# CER
# ref: 좀 많이 좋긴 한데 근데 그렇게 적은 것 같아 2000이라고 그 정도면
# hyp: 좀 많긴 한데 근데 그렇게 적은 것 같아 2천이라고 그 정도면
# or 0.20833333333333334
# my 0.13114754098360656
# ----------
# CER
# ref: 세스코도 7만 2천 원 이것도 여기 센 거야
# hyp: 세고 세스코도 7만 2천 원 이것도 좀 센 거야
# or 0.2222222222222222
# my 0.22857142857142856
# ----------
# CER
# ref: 도와주니까 고맙진 않을까 내가 모르는 부분이었어 커피 마트고 잡아주 이런 것도 잘 해야 될 것 같다 거기까지 왔어 가면 더 사람은 없어서
# hyp: 도와주니까 고맙지 나는 내가 모르는 부분이 있었고 커피 맛도 잡아주고 막 이런것도 잘해주고 하니까 거기까진 좋았지 가면 갈수록 선을 넘는 거야 계속
# or 0.366120218579235
# my 0.4496124031007752
# ----------
# CER
# ref: 지금 적자 이거 하면 안 됐어 적자고 내 언니한테 말했지 않냐고 적자고 상황으로 좀 그렇지 내가 굿즈를 재석한다는 게 시기상조라고
# hyp: 지금 적자고 얼마 안됐어 적다고 내가 언니한테 말했잖냐 적자고 지금 상황을 굳이 내가 굿즈를 제작한다는 게 시기상조라고
# or 0.2733333333333333
# my 0.2421875
# ----------
# CER
# ref: 위행하고 있는 그것도 봐야 되고 하니까 나는 그런 생각으로 이렇게 한다고 하거든요 그러려고 하거든
# hyp: 유행하고 있는 그것도 봐야 되고 하니까 나는 그런 생각으로 이렇게 쉰다고 하거든요 쉬려고 하거든
# or 0.06666666666666667
# my 0.07446808510638298
# ----------
# CER
# ref: 그치
# hyp: 되지
# or 0.5
# my 0.75
# ----------
# CER
# ref: 나는 처음이야 안 해본 거고 생각할 일도
# hyp: 전혀 안 해봤던 거고 생각할 일도
# or 0.5384615384615384
# my 0.425
# ----------
# CER
# ref: 매해 엄마가 늦게
# hyp: 내가 먹어주께
# or 0.7222222222222222
# my 0.75
# ----------
# CER
# ref: 했더니 그게 다 있던 사람들 다 그런 반응이더래 물어봤더니 쓸개 떼는 게 낫다고 그런 얘기를 해
# hyp: 했더니 그게 다 있던 사람들 다 그런 반응이더래 물어봤더니 쓸개 떼는 게 낫다고 그런 얘기를 하더래
# or 0.05833333333333333
# my 0.04395604395604396
# ----------
# CER
# ref: 이분이 누구한테 쓰다는 거 앞에 있고
# hyp: 이분이 누구한테 식당을 맡기고
# or 0.41025641025641024
# my 0.4
# ----------
# CER
# ref: 그런 거를 자꾸 나누고 그 이후에 한번 캐쳐에 한번 했자말이야 책을 보고 이렇게 하는 게 있어
# hyp: 그런 걸 자꾸 나 공유해 한 번 해주길래 한 번 했단 말이야 책을 보고 이제 이렇게 하는 게 있어요
# or 0.3153153153153153
# my 0.2988505747126437
# ----------
# CER
# ref: 어 그래서 그런 거 자꾸 자기도 자기도 막 하라고 했는데 새까대
# hyp: 어 그래서 그런 것도 자꾸 자기도 막 하라는데 쌩깟데
# or 0.3333333333333333
# my 0.3148148148148148
# ----------
# CER
# ref: 근년하겠어요
# hyp: 심난하겠다
# or 0.5999999999999999
# my 0.5333333333333333
# ----------
# CER
# ref: 어
# hyp: 아
# or 0.3333333333333333
# my 0.5
# ----------
# CER
# ref: 낙지 이후에는 이제 사람들은 약간 시간 조정을 할까 했는데 시간 굳이 여기 있으면서 하는 것보다 진짜
# hyp: 5시 이후에는 이제 사람들이 약간 시간 조정을 할까 했는데 시간 굳이 여기 있으면서 하는 것보다 진짜
# or 0.04878048780487805
# my 0.058823529411764705
# ----------
# CER
# ref: 아우 매장하다
# hyp: 아우 불쌍하다
# or 0.2222222222222222
# my 0.3076923076923077
# ----------
# CER
# ref: 어우 매출이 부터 100이라니요 막 쪼떼도 하더니 좀 더 생각해보고 연락드린다고
# hyp: 어우 매출이 그정도인데 백이라니요 이러고 어쩌고저쩌고 하더니 좀 더 생각해보고 연락드린다고
# or 0.31666666666666665
# my 0.4
# ----------
# CER
# ref: 왜 진구하면서 와서
# hyp: 왜 왜 중간에 추월하지
# or 0.7037037037037037
# my 0.9444444444444444
# ----------
# CER
# ref: 저번 쪽에 하나 사가지고 먹었단 말이에요 근데 약간 냄새가 나는 것 같아서 좀 한 방법을 바꿨냐 이렇게 물어봤어
# hyp: 저번 주에 하나 더 사가지고 먹었단 말이야약간 냄새가 나는것 같아서 하는 방법을 바꿨냐 그렇게 물어봤어
# or 0.1782945736434109
# my 0.17857142857142858
# ----------
# CER
# ref: 어 직원들도 막 붙겠는데
# hyp: 어 직원들도 막 죽겠는데
# or 0.06666666666666667
# my 0.07407407407407407
# ----------
# CER
# ref: 아
# hyp: 어
# or 0.3333333333333333
# my 0.5
# ----------
# CER
# ref: 위엄냐 위엄냐고
# hyp: 왜 없냐 왜 없냐고
# or 0.19047619047619047
# my 0.25
# ----------
# CER
# ref: 암웨이가 계속 올린것으로 알았는데
# hyp: 암웨이가 계속 그렇게 모임 같은 걸 한대
# or 0.4583333333333333
# my 0.5526315789473685
# ----------
# CER
# ref: 엄마가 밥을 먹고 사야지 어 아까 먹었어 그럴 때도 있어 이제 빵에 빵에서 이렇게 뭐 시켜야 되는데 보고 있다가
# hyp: 엄마가 밥은 먹고 자야지 아까 먹었어 그러고 그럴 때도 있어 쿠팡에 쿠팡에서 이렇게 뭘 시켜야 되는데 보고 있다가
# or 0.18115942028985504
# my 0.18811881188118812
# ----------
# CER
# ref: 어재
# hyp: 어
# or 1.0
# my 0.5
# ----------
# CER
# ref: 지금 맞춰
# hyp: 지금 빨리 사
# or 0.4666666666666666
# my 0.6
# ----------
# CER
# ref: 딸들이 고생이다 딸들이
# hyp: 딸들이 고생이다 딸들
# or 0.1111111111111111
# my 0.08
# ----------
# CER
# ref: 그렇게 해서 그렇게 해야 될 거 같아
# hyp: 그렇게 해서 그렇게 해야 될 것 같아
# or 0.023809523809523808
# my 0.03125
# ----------
# SER: 33.98%
# CER: 27.52%
# INS SER: 7.93%
# DEL SER: 3.69%
# SUB SER: 22.36%
# INS CER: 8.88%
# DEL CER: 4.08%
# SUB CER: 14.56%

# %%
ref= '그게 오는 거래'
hyp= '떼오는 거래'

numCor2, numSub2, numDel2, numIns2, cer_score, lines, total2 = cer(ref, hyp, debug=True)
# Out:
# DEL	ㄱ	****
# DEL	ㅡ	****
# SUB	ㄱ	ㄸ
# OK	ㅔ	ㅔ
# OK	ㅇ	ㅇ
# OK	ㅗ	ㅗ
# OK	ㄴ	ㄴ
# OK	ㅡ	ㅡ
# OK	ㄴ	ㄴ
# OK	ㄱ	ㄱ
# OK	ㅓ	ㅓ
# OK	ㄹ	ㄹ
# OK	ㅐ	ㅐ
# Ncor 10
# Nsub 1
# Ndel 2
# Nins 0
# WER 0.23076923076923078
